# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone -b 327797 https://github.com/parmigggiana/polito-task-arithmetic.git
# %cd polito-task-arithmetic
# %mkdir out
# %mkdir out_wd
# %pip install gdown open-clip-torch torch torchvision tqdm scipy pillow numpy

# %%
# Only run this once to download the datasets to your Google Drive
import os
import gdown
import zipfile

url = 'https://drive.google.com/drive/folders/1BiK9sYyTslcxQQoS3vZGF02hRg6OQpR4?usp=sharing'
folder_id = url.split('/')[-1].split('?')[0]
gdown.download_folder(f'https://drive.google.com/drive/folders/{folder_id}', quiet=False)


source_dir = 'Task Arithmetic Datasets'
target_dir = '/content/drive/MyDrive/polito_task_arithmetic_data/data'

if not os.path.exists(target_dir):
    os.makedirs(target_dir)

for file_name in os.listdir(source_dir):
    file_path = os.path.join(source_dir, file_name)
    target_path = target_dir

    with zipfile.ZipFile(file_path, 'r') as zip_ref:
        zip_ref.extractall(target_path)
        print(f'Unzipped {file_name} to {target_path}')

# %%
# base.sh

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=1e-4 \
--wd=0.0

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out/ \
--cache-dir=./cache/

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out/ \
--cache-dir=./cache/

# %%
# wd.sh

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_3/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=1e-4 \
--wd=0.001

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_3/ \
--cache-dir=./cache/

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_3/ \
--cache-dir=./cache/ \
--alpha=0.15

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_2/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=1e-4 \
--wd=0.01

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_2/ \
--cache-dir=./cache/

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_2/ \
--cache-dir=./cache/ \
--alpha=0.15

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_1/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=1e-4 \
--wd=0.1

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_1/ \
--cache-dir=./cache/

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_wd_1/ \
--cache-dir=./cache/ \
--alpha=0.15

# %%
# lr.sh

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_3/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=5e-4

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_3/ \
--cache-dir=./cache/ \

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_3/ \
--cache-dir=./cache/ \
--alpha=0.15

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_2/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=5e-5

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_2/ \
--cache-dir=./cache/

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_2/ \
--cache-dir=./cache/ \
--alpha=0.15

# !python finetune.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_1/ \
--cache-dir=./cache/ \
--batch-size=32 \
--lr=1e-5

# !python eval_single_task.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_1/ \
--cache-dir=./cache/ \

# !python eval_task_addition.py \
--data-location=/content/drive/MyDrive/polito_task_arithmetic_data/data/ \
--save=/content/drive/MyDrive/polito_task_arithmetic_data/out_lr_1/ \
--cache-dir=./cache/ \
--alpha=0.15

# %%
drive.flush_and_unmount() # Ensure all changes are saved before unmounting
print("All tasks completed and changes saved to Google Drive.")
